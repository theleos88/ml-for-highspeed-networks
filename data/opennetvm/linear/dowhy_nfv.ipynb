# %% [markdown]
# # Basic Example for Calculating the Causal Effect
# This is a quick introduction to the DoWhy causal inference library.
# We will load in a sample dataset and estimate the causal effect of a (pre-specified) treatment variable on a (pre-specified) outcome variable.
#
# First, let us load all required packages.

# %%
import numpy as np

from dowhy import CausalModel
import dowhy.datasets

# %% [markdown]
# Now, let us load a dataset. For simplicity, we simulate a dataset with linear relationships between common causes and treatment, and common causes and outcome.
#
# Beta is the true causal effect.

# %% [markdown]
# data = dowhy.datasets.linear_dataset(beta=10,
#         num_common_causes=5,
#         num_instruments = 2,
#         num_effect_modifiers=1,
#         num_samples=5000,
#         treatment_is_binary=True,
#         stddev_treatment_noise=10,
#         num_discrete_common_causes=1)
# df = data["df"]

# %%
import pandas as pd

# %%
df = pd.read_csv("resource_stimulus_exp37.csv")

# %%
df.head()
# Out:
#    Unnamed: 0   input_rate  output_rate  latency  firewall_instructions  \
# 0           0   437.930816   404.127828   10.365           9.751822e+09
# 1           1  1913.255477  2085.342228    9.708           9.835258e+09
# 2           2  2112.830688  2109.307818   10.788           9.664052e+09
# 3           3  2113.348796  2110.105127    9.049           9.715116e+09
# 4           4  2112.254122  2109.289185    6.771           7.708181e+09
#
#    nf_router_instructions  ndpi_stats_instructions  payload_scan_instructions  \
# 0            1.023718e+10             1.006349e+10               1.008585e+10
# 1            1.022678e+10             1.007585e+10               9.983788e+09
# 2            1.011455e+10             1.006045e+10               9.978947e+09
# 3            1.013541e+10             1.006567e+10               1.008519e+10
# 4            1.002701e+10             9.987993e+09               9.983456e+09
#
# ...

# %% [markdown]
# Note that we are using a pandas dataframe to load the data. At present, DoWhy only supports pandas dataframe as input.

# %% [markdown]
# ## Interface 1 (recommended): Input causal graph

# %% [markdown]
# We now input a causal graph in the GML graph format (recommended). You can also use the DOT format.
#
# To create the causal graph for your dataset, you can use a tool like [DAGitty](http://dagitty.net/dags.html#) that provides a GUI to construct the graph. You can export the graph string that it generates. The graph string is very close to the DOT format: just rename `dag` to `digraph`, remove newlines and add a semicolon after every line, to convert it to the DOT format and input to DoWhy.

# %% [markdown]
# # With graph
# model=CausalModel(
#         data = df,
#         treatment=data["treatment_name"],
#         outcome=data["outcome_name"],
#         graph=data["gml_graph"]
#         )

# %%
gml = """graph[
    directed 1
    node[ id "input_rate" label "input_rate"]
    node[ id "output_rate" label "output_rate"]
    node[ id "firewall_cycles" label "firewall_cycles"]
    node[ id "latency" label "latency"]
    node[ id "firewall_output" label "firewall"]
    edge[source "input_rate" target "output_rate"]
    edge[source "bridge_cycles" target "output_rate"]
    edge[source "bridge_cycles" target "latency"]
    edge[source "input_rate" target "latency"]
    edge[source "input_rate" target "bridge_L1-dcache-load-misses"]
    edge[source "bridge_L1-dcache-load-misses" target "output_rate"]
    edge[source "bridge_L1-dcache-load-misses" target "latency"]
]"""

# %%
data = df[["input_rate", "output_rate", "latency", "bridge_cycles", "bridge_L1-dcache-load-misses"]]
data
# Out:
#      input_rate  output_rate    latency  bridge_cycles  \
# 0    437.930816   404.127828     10.365   2.723093e+09
# 1   1913.255477  2085.342228      9.708   2.891631e+09
# 2   2112.830688  2109.307818     10.788   2.892075e+09
# 3   2113.348796  2110.105127      9.049   2.891610e+09
# 4   2112.254122  2109.289185      6.771   2.891543e+09
# 5   2113.027378  2109.316203      7.223   2.891821e+09
# 6   2113.010217  2109.197971      8.540   2.891973e+09
# 7   2113.113681  2108.829512      6.598   2.891873e+09
# 8   2113.250693  2109.619997      9.658   2.891519e+09
# 9   2112.836312  2109.213679      8.714   2.584616e+09
# 10  2113.095974  2108.515682     10.119   2.891895e+09
# 11  2112.879345  1933.673538      8.538   2.892139e+09
# 12  2112.873410   826.261544      7.450   2.891957e+09
# 13  2113.323512   803.387790     10.461   2.892438e+09
# 14  2113.181725   727.660184      8.588   2.892332e+09
# 15  2113.114429   777.448742      7.414   2.892400e+09
# ...

# %%
model=CausalModel(
        data = data,
        treatment=["input_rate"],
        outcome="latency",
        graph=gml
        )

# %%
model.view_model()

# %%
from IPython.display import Image, display
display(Image(filename="causal_model.png"))

# %% [markdown]
# The above causal graph shows the assumptions encoded in the causal model. We can now use this graph to first identify
# the causal effect (go from a causal estimand to a probability expression), and then estimate the causal effect.

# %% [markdown]
# ### DoWhy philosophy: Keep identification and estimation separate
#
# Identification can be achieved without access to the data, acccesing only the graph. This results in an expression to be computed. This expression can then be evaluated using the available data in the estimation step.
# It is important to understand that these are orthogonal steps.
#
# #### Identification

# %%
identified_estimand = model.identify_effect(proceed_when_unidentifiable=True)
print(identified_estimand)
# Out:
# Estimand type: EstimandType.NONPARAMETRIC_ATE
#
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#      d
# ────────────(E[latency])
# d[inputᵣₐₜₑ]
# Estimand assumption 1, Unconfoundedness: If U→{input_rate} and U→latency then P(latency|input_rate,,U) = P(latency|input_rate,)
#
# ### Estimand : 2
# Estimand name: iv
# No such variable(s) found!
#
# ### Estimand : 3
# Estimand name: frontdoor
# No such variable(s) found!

# %% [markdown]
# Note the parameter flag *proceed\_when\_unidentifiable*. It needs to be set to *True* to convey the assumption that we are ignoring any unobserved confounding. The default behavior is to prompt the user to double-check that the unobserved confounders can be ignored.

# %% [markdown]
# #### Estimation

# %%
causal_estimate = model.estimate_effect(identified_estimand,
        method_name="backdoor.linear_regression")
print(causal_estimate)
# Out:
# *** Causal Estimate ***
#
# ## Identified estimand
# Estimand type: EstimandType.NONPARAMETRIC_ATE
#
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#      d
# ────────────(E[latency])
# d[inputᵣₐₜₑ]
# Estimand assumption 1, Unconfoundedness: If U→{input_rate} and U→latency then P(latency|input_rate,,U) = P(latency|input_rate,)
#
# ## Realized estimand
# b: latency~input_rate+input_rate*bridge_cycles
# Target units: ate
#
# ## Estimate
# Mean value: 3.9356085869605977

# %% [markdown]
# You can input additional parameters to the estimate_effect method. For instance, to estimate the effect on any subset of the units, you can specify the "target_units" parameter which can be a string ("ate", "att", or "atc"), lambda function that filters rows of the data frame, or a new dataframe on which to compute the effect. You can also specify "effect modifiers" to estimate heterogeneous effects across these variables. See `help(CausalModel.estimate_effect)`.

# %%
# Causal effect on the control group (ATC)
causal_estimate_att = model.estimate_effect(identified_estimand,
        method_name="backdoor.linear_regression",
        target_units="atc")

print(causal_estimate_att)
print("Causal Estimate is " + str(causal_estimate_att.value))
# Out:
# *** Causal Estimate ***
#
# ## Identified estimand
# Estimand type: EstimandType.NONPARAMETRIC_ATE
#
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#      d
# ────────────(E[latency])
# d[inputᵣₐₜₑ]
# Estimand assumption 1, Unconfoundedness: If U→{input_rate} and U→latency then P(latency|input_rate,,U) = P(latency|input_rate,)
#
# ## Realized estimand
# b: latency~input_rate+input_rate*bridge_cycles
# Target units: atc
#
# ## Estimate
# Mean value: 3.9356085869605977
#
# Causal Estimate is 3.9356085869605977

# %% [markdown]
# ### Resource stimulus experiments

# %%
df[["firewall_cycles","nf_router_cycles","ndpi_stats_cycles","payload_scan_cycles","bridge_cycles"]].plot()
# Out:
# <AxesSubplot: >

# %%
gml = """graph[
    directed 1
    node[ id "input_rate" label "input_rate"]
    node[ id "output_rate" label "output_rate"]
    node[ id "ndpi_stats_cycles" label "ndpi_stats_cycles"]
    node[ id "latency" label "latency"]
    node[ id "ndpi_stats_L1-dcache-load-misses" label "ndpi_stats_L1-dcache-load-misses"]
    edge[source "input_rate" target "output_rate"]
    edge[source "ndpi_stats_cycles" target "output_rate"]
    edge[source "ndpi_stats_cycles" target "latency"]
    edge[source "input_rate" target "latency"]
    edge[source "input_rate" target "ndpi_stats_L1-dcache-load-misses"]
    edge[source "ndpi_stats_L1-dcache-load-misses" target "output_rate"]
    edge[source "ndpi_stats_L1-dcache-load-misses" target "latency"]
]"""

data = df[["input_rate", "output_rate", "latency", "ndpi_stats_cycles", "ndpi_stats_L1-dcache-load-misses"]]
data
# Out:
#      input_rate  output_rate    latency  ndpi_stats_cycles  \
# 0    437.930816   404.127828     10.365       2.893078e+09
# 1   1913.255477  2085.342228      9.708       2.891828e+09
# 2   2112.830688  2109.307818     10.788       2.891901e+09
# 3   2113.348796  2110.105127      9.049       2.891746e+09
# 4   2112.254122  2109.289185      6.771       2.891605e+09
# 5   2113.027378  2109.316203      7.223       2.891793e+09
# 6   2113.010217  2109.197971      8.540       2.721988e+09
# 7   2113.113681  2108.829512      6.598       2.891924e+09
# 8   2113.250693  2109.619997      9.658       2.891755e+09
# 9   2112.836312  2109.213679      8.714       2.891661e+09
# 10  2113.095974  2108.515682     10.119       2.887756e+09
# 11  2112.879345  1933.673538      8.538       7.289766e+08
# 12  2112.873410   826.261544      7.450       7.322723e+08
# 13  2113.323512   803.387790     10.461       7.170412e+08
# 14  2113.181725   727.660184      8.588       7.157922e+08
# ...

# %%
model=CausalModel(
        data = data,
        treatment=["ndpi_stats_cycles"],
        outcome="output_rate",
        graph=gml
        )
model.view_model()

# %%
identified_estimand = model.identify_effect(proceed_when_unidentifiable=True)
print(identified_estimand)
# Out:
# Estimand type: EstimandType.NONPARAMETRIC_ATE
#
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#          d
# ────────────────────(E[outputᵣₐₜₑ])
# d[ndpi_stats_cycles]
# Estimand assumption 1, Unconfoundedness: If U→{ndpi_stats_cycles} and U→output_rate then P(output_rate|ndpi_stats_cycles,,U) = P(output_rate|ndpi_stats_cycles,)
#
# ### Estimand : 2
# Estimand name: iv
# No such variable(s) found!
#
# ### Estimand : 3
# Estimand name: frontdoor
# No such variable(s) found!

# %%
causal_estimate = model.estimate_effect(identified_estimand,
        method_name="backdoor.linear_regression")
print(causal_estimate)
# Out:
# *** Causal Estimate ***
#
# ## Identified estimand
# Estimand type: EstimandType.NONPARAMETRIC_ATE
#
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#          d
# ────────────────────(E[outputᵣₐₜₑ])
# d[ndpi_stats_cycles]
# Estimand assumption 1, Unconfoundedness: If U→{ndpi_stats_cycles} and U→output_rate then P(output_rate|ndpi_stats_cycles,,U) = P(output_rate|ndpi_stats_cycles,)
#
# ## Realized estimand
# b: output_rate~ndpi_stats_cycles+ndpi_stats_cycles*ndpi_stats_L1-dcache-load-misses+ndpi_stats_cycles*input_rate
# Target units: ate
#
# ## Estimate
# Mean value: 9.127784977031686e-07

# %%
df["ndpi_stats_cycles"].corr(df["output_rate"])
# Out:
# 0.8475069349380673

# %%
df["ndpi_stats_cycles"].corr(df["output_rate"], method="kendall")
# Out:
# 0.4897435897435898

# %%
df["ndpi_stats_cycles"].corr(df["output_rate"], method="spearman")
# Out:
# 0.6675422138836774

# %%
df["input_rate"].corr(df["output_rate"])
# Out:
# 0.21850836429220535

# %%
df["input_rate"].corr(df["output_rate"], method="kendall")
# Out:
# -0.07692307692307694

# %%
df["input_rate"].corr(df["output_rate"], method="spearman")
# Out:
# -0.09249530956848032
