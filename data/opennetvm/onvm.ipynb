# %%
import sys, re
import matplotlib.pyplot as plt
import numpy as np

# %%
def get_stat(stat_name, source="general/fastclick-varied-cbr-rates.csv"):
    stat = []
    with open(source) as file:
        for line in file:
            if re.search(stat_name, line):
                stat.append(line.strip().split(',')[1])
    
    return list(map(lambda x:float(x), stat[:-1]))

def plot_stat(stat_name, ax, source):
    stat = get_stat(stat_name, source)
    ax.plot(stat)
    ax.set_title(stat_name)

def plot_stats(stat_names, source="fastclick-varied-cbr-rates.csv"):
    i = 1
    fig, ax = plt.subplots(len(stat_names),1)
    for s in stat_names:
        ax = plt.subplot(len(stat_names),1, i)
        plot_stat(s, ax, source)
        i+=1
    fig.tight_layout()

# %% [markdown]
# ## Service chain configuration:
#
# ### OpenNetVM:  NIC --> firewall --> nDPI --> router --> payload scan --> bridge --> NIC

# %% [markdown]
# # Resource stimulus

# %%
with open("sfc1/resource_stimulus/tx_stats.csv") as file:
    next(file)
    tmp = []
    for line in file:
        tmp.append(float(line.strip().split(",")[5]))

plt.ylabel("Input traffic rate [Mbps]")
plt.plot(tmp)

# %%
with open("sfc1/resource_stimulus/rx_stats.csv") as file:
    next(file)
    tmp = []
    for line in file:
        tmp.append(float(line.strip().split(",")[5]))

plt.ylabel("Output traffic rate [Mbps]")
plt.plot(tmp)

# %%
with open("sfc1/resource_stimulus/latency.csv") as file:
    tmp = []
    for line in file:
        tmp.append(float(line.strip())/1000)

plt.ylabel("Latency [us]")
#plt.ylim(1,100)
plt.yscale("log")
plt.title("End-to-end latency (log scale)")
plt.plot(0.5*np.arange(0, len(tmp)), tmp)

# %%
plot_stats(["instructions"], "sfc1/resource_stimulus/firewall.csv")

# %%
plot_stats(["branches,", "branch-misses", "branch-load-misses"], "sfc1/resource_stimulus/firewall.csv")

# %%
plot_stats(["cache-misses", "cache-references"], "sfc1/resource_stimulus/firewall.csv")

# %%
plot_stats([",cycles,", "cpu-clock", "task-clock",], "sfc1/resource_stimulus/firewall.csv")

# %%
plot_stats(["minor-faults", "page-faults"], "sfc1/resource_stimulus/firewall.csv")

# %%
plot_stats(["bus-cycles", "ref-cycles"], "sfc1/resource_stimulus/firewall.csv")

# %%
plot_stats(["L1-icache-load-misses", "L1-dcache-load-misses", "L1-dcache-loads", "L1-dcache-stores"], "sfc1/resource_stimulus/firewall.csv")

# %%
plot_stats(["LLC-stores", "LLC-loads"], "sfc1/resource_stimulus/firewall.csv")

# %%
plot_stats(["LLC-load-misses", "LLC-store-misses"], "sfc1/resource_stimulus/firewall.csv")

# %%
plot_stats(["dTLB-stores", "dTLB-load-misses", "dTLB-store-misses"], "sfc1/resource_stimulus/firewall.csv")

# %%
plot_stats(["iTLB-loads", "iTLB-load-misses"], "sfc1/resource_stimulus/firewall.csv")

# %%
plot_stats(["node-load-misses", "node-loads", "node-store-misses", "node-stores"], "sfc1/resource_stimulus/firewall.csv")

# %% [markdown]
# # Load stimulus

# %%
with open("sfc2/load_stimulus/exp1/tx_stats.csv") as file:
    next(file)
    tmp = []
    for line in file:
        tmp.append(float(line.strip().split(",")[5]))

plt.ylabel("Input traffic rate [Mbps]")
plt.plot(tmp)

# %%
with open("sfc2/load_stimulus/exp4/rx_stats.csv") as file:
    next(file)
    tmp = []
    for line in file:
        tmp.append(float(line.strip().split(",")[5]))

plt.ylabel("Input traffic rate [Mbps]")
plt.plot(tmp)

# %%
with open("sfc2/load_stimulus/exp9/latency.csv") as file:
    tmp = []
    for line in file:
        tmp.append(float(line.strip())/100)

plt.ylabel("Latency [ns]")
plt.plot(0.5*np.arange(0, len(tmp)), tmp)

# %%
plot_stats(["instructions"], "sfc1/load_stimulus/firewall.csv")

# %%
plot_stats(["instructions"], "sfc1/load_stimulus/ndpi_stats.csv")

# %%
plot_stats(["instructions"], "sfc1/load_stimulus/nf_router.csv")

# %%
plot_stats(["instructions"], "sfc1/load_stimulus/payload_scan.csv")

# %%
plot_stats(["instructions"], "sfc1/load_stimulus/bridge.csv")

# %%
plot_stats(["branches,", "branch-misses", "branch-load-misses"], "sfc1/load_stimulus/firewall.csv")

# %%
plot_stats(["branches,", "branch-misses", "branch-load-misses"], "sfc2/load_stimulus/exp9/ndpi_stats.csv")

# %%
plot_stats(["branches,", "branch-misses", "branch-load-misses"], "sfc1/load_stimulus/nf_router.csv")

# %%
plot_stats(["branches,", "branch-misses", "branch-load-misses"], "sfc2/load_stimulus/exp4/payload_scan.csv")

# %%
plot_stats(["branches,", "branch-misses", "branch-load-misses"], "sfc2/load_stimulus/exp4/bridge.csv")

# %%
plot_stats(["cache-misses", "cache-references"], "sfc2/load_stimulus/exp9/firewall.csv")

# %%
plot_stats(["cache-misses", "cache-references"], "sfc2/load_stimulus/exp5/ndpi_stats.csv")

# %%
plot_stats(["cache-misses", "cache-references"], "sfc2/load_stimulus/exp1/nf_router.csv")

# %%
plot_stats(["cache-misses", "cache-references"], "sfc2/load_stimulus/exp10/payload_scan.csv")

# %%
plot_stats(["cache-misses", "cache-references"], "sfc2/load_stimulus/exp3/bridge.csv")

# %%
plot_stats(["bus-cycles", "ref-cycles"], "sfc2/load_stimulus/exp10/firewall.csv")

# %%
plot_stats(["bus-cycles", "ref-cycles"], "sfc2/load_stimulus/exp3/ndpi_stats.csv")

# %%
plot_stats(["bus-cycles", "ref-cycles"], "sfc1/load_stimulus/nf_router.csv")

# %%
plot_stats(["bus-cycles", "ref-cycles"], "sfc1/load_stimulus/payload_scan.csv")

# %%
plot_stats(["bus-cycles", "ref-cycles"], "sfc1/load_stimulus/bridge.csv")

# %%
plot_stats(["L1-icache-load-misses", "L1-dcache-load-misses", "L1-dcache-loads", "L1-dcache-stores"], "sfc1/load_stimulus/firewall.csv")

# %%
plot_stats(["L1-icache-load-misses", "L1-dcache-load-misses", "L1-dcache-loads", "L1-dcache-stores"], "sfc1/load_stimulus/ndpi_stats.csv")

# %%
plot_stats(["L1-icache-load-misses", "L1-dcache-load-misses", "L1-dcache-loads", "L1-dcache-stores"], "sfc1/load_stimulus/nf_router.csv")

# %%
plot_stats(["L1-icache-load-misses", "L1-dcache-load-misses", "L1-dcache-loads", "L1-dcache-stores"], "sfc1/load_stimulus/payload_scan.csv")

# %%
plot_stats(["L1-icache-load-misses", "L1-dcache-load-misses", "L1-dcache-loads", "L1-dcache-stores"], "sfc1/load_stimulus/bridge.csv")

# %%
plot_stats(["LLC-stores", "LLC-loads"], "sfc1/load_stimulus/firewall.csv")

# %%
plot_stats(["LLC-stores", "LLC-loads"], "sfc1/load_stimulus/ndpi_stats.csv")

# %%
plot_stats(["minor-faults", "page-faults"], "sfc1/load_stimulus/firewall.csv")

# %%
plot_stats([",cycles,", "cpu-clock", "task-clock",], "sfc1/load_stimulus/firewall.csv")

# %%
plot_stats(["dTLB-stores", "dTLB-load-misses", "dTLB-store-misses"], "sfc1/load_stimulus/firewall.csv")

# %%
with open("sfc1/latency.csv") as file:
    tmp = []
    for line in file:
        tmp.append(float(line.strip())/100)

plt.ylabel("Latency [ns]")
plt.yscale("log")
plt.plot(0.5*np.arange(0, len(tmp)), tmp)

# %%
plot_stats(["branches,", "branch-misses", "branch-load-misses"], "sfc1/firewall.csv")

# %%
plot_stats(["branches,", "branch-misses", "branch-load-misses"], "sfc1/ndpi_stats.csv")

# %%
plot_stats(["branches,", "branch-misses", "branch-load-misses"], "sfc1/nf_router.csv")

# %%
plot_stats(["branches,", "branch-misses", "branch-load-misses"], "sfc1/payload_scan.csv")

# %%
plot_stats(["branches,", "branch-misses", "branch-load-misses"], "sfc1/bridge.csv")

# %%
plot_stats(["dTLB-stores", "dTLB-load-misses", "dTLB-store-misses"], "sfc1/firewall.csv")

# %%
plot_stats(["dTLB-stores", "dTLB-load-misses", "dTLB-store-misses"], "sfc1/nf_router.csv")

# %%
plot_stats(["dTLB-stores", "dTLB-load-misses", "dTLB-store-misses"], "sfc1/ndpi_stats.csv")

# %%
plot_stats(["L1-icache-load-misses", "L1-dcache-load-misses", "L1-dcache-loads", "L1-dcache-stores"], "sfc1/firewall.csv")

# %%
plot_stats(["L1-icache-load-misses", "L1-dcache-load-misses", "L1-dcache-loads", "L1-dcache-stores"], "sfc1/ndpi_stats.csv")

# %%
plot_stats(["L1-icache-load-misses", "L1-dcache-load-misses", "L1-dcache-loads", "L1-dcache-stores"], "sfc1/nf_router.csv")

# %%
plot_stats(["L1-icache-load-misses", "L1-dcache-load-misses", "L1-dcache-loads", "L1-dcache-stores"], "sfc1/payload_scan.csv")

# %%
plot_stats(["L1-icache-load-misses", "L1-dcache-load-misses", "L1-dcache-loads", "L1-dcache-stores"], "sfc1/bridge.csv")

# %%
plot_stats(["bus-cycles", "ref-cycles"], "sfc1/firewall.csv")

# %%
plot_stats(["bus-cycles", "ref-cycles"], "sfc1/ndpi_stats.csv")

# %%
plot_stats(["bus-cycles", "ref-cycles"], "sfc1/nf_router.csv")

# %%
plot_stats(["bus-cycles", "ref-cycles"], "sfc1/payload_scan.csv")

# %%
plot_stats(["bus-cycles", "ref-cycles"], "sfc1/bridge.csv")

# %%
plot_stats(["bus-cycles", "ref-cycles"], "sfc1/ndpi_stats.csv")
